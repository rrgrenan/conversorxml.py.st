# %%
pip install pyautogui
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyautogui as pa
import time

# %%
time.sleep(7)

print(pa.position())
# Out:
# Point(x=424, y=360)

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import openpyxl

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_excel(r"C:\Users\User100\Documents\Arquivos Renan\from drive\Dimensões pro site.xlsx")
# Out:
#                 Unnamed: 0         Unnamed: 1 Unnamed: 2
# 0                      NaN                NaN        NaN
# 1         Rótulos de Linha  Contagem de MARCA     Status
# 2                  JASMYNE                  7        NaN
# 3                 LUISANCE                  7    Tray ok
# 4                    Dalla                  8    Tray ok
# 5                   LYRICS                  9        NaN
# 6                   Makiaj                 10        NaN
# 7              BELLA FEMME                 14        NaN
# 8                  Febella                 14    Tray ok
# 9                 LA BENIG                 15        NaN
# 10                 PLAYBOY                 22        NaN
# 11                 Mundial                 26        NaN
# 12             MISS FRANCE                 27        NaN
# 13       Algodão e Acetona                 33        NaN
# 14                   Mahav                 34        NaN
# ...
