# %%
# Prompt: Rodar um código que acesse a minha pasta, copie o nome de cada arquivo
# e cole em celulas de um excel ou print aqui no terminal

# 1 - Acessar pasta
# 2 - Ler o nome dos arquivos
# 3 - Copiar o nome do arquivo
# 4 - Printar no terminal

# %%
import pandas as pd
import os
import glob
from PIL import Image

# %%
caminho_pasta = r'C:\Users\USER\Documents\Planilhas Renan\codes\Imagem com erro'

# %%
# Verificar se a pasta existe
if not os.path.exists(caminho_pasta):
    print(f"A pasta '{caminho_pasta}' não existe.")
else:
    # Listar todos os arquivos de imagem na pasta (considerando várias extensões de imagem)
    extensoes_imagem = ['*.jpg', '*.jpeg', '*.png', '*.gif', '*.bmp', '*.tiff']

    # Criar uma lista para armazenar os nomes dos arquivos de imagem
    arquivos_imagens = []

    # Iterar por cada extensão e adicionar os arquivos encontrados à lista
    for extensao in extensoes_imagem:
        arquivos_encontrados = glob.glob(os.path.join(caminho_pasta, extensao))
        print(f"Arquivos encontrados para a extensão {extensao}: {arquivos_encontrados}")
        arquivos_imagens.extend(arquivos_encontrados)

    # Verificar se encontramos algum arquivo de imagem
    if not arquivos_imagens:
        print("Nenhum arquivo de imagem encontrado na pasta especificada.")
    else:
        # Exibir os nomes dos arquivos de imagem
        for arquivo in arquivos_imagens:
            print(os.path.basename(arquivo))
# Out:
# Arquivos encontrados para a extensão *.jpg: []
# Arquivos encontrados para a extensão *.jpeg: []
# Arquivos encontrados para a extensão *.png: ['C:\\Users\\USER\\Documents\\Planilhas Renan\\codes\\Imagem com erro\\(313 À 316).png', 'C:\\Users\\USER\\Documents\\Planilhas Renan\\codes\\Imagem com erro\\1028.png', 'C:\\Users\\USER\\Documents\\Planilhas Renan\\codes\\Imagem com erro\\10G.png', 'C:\\Users\\USER\\Documents\\Planilhas Renan\\codes\\Imagem com erro\\114.3.png', 'C:\\Users\\USER\\Documents\\Planilhas Renan\\codes\\Imagem com erro\\122.png', 'C:\\Users\\USER\\Documents\\Planilhas Renan\\codes\\Imagem com erro\\134.png', 'C:\\Users\\USER\\Documents\\Planilhas Renan\\codes\\Imagem com erro\\1427.png', 'C:\\Users\\USER\\Documents\\Planilhas Renan\\codes\\Imagem com erro\\1452.png', 'C:\\Users\\USER\\Documents\\Planilhas Renan\\codes\\Imagem com erro\\1722.png', 'C:\\Users\\USER\\Documents\\Planilhas Renan\\codes\\Imagem com erro\\173.png', 'C:\\Users\\USER\\Documents\\Planilhas Renan\\codes\\Imagem com erro\\2024.png', 'C:\\Users\\USER\\Documents\\Planilhas Renan\\codes\\Imagem com erro\\2069.png', 'C:\\Users\\USER\\Documents\\Planilhas Renan\\codes\\Imagem com erro\\2076.png', 'C:\\Users\\USER\\Documents\\Planilhas Renan\\codes\\Imagem com erro\\2182.png', 
has Renan\\codes\\Imagem com erro\\37.png', 'C:\\Users\\USER\\Documents\\Planilhas Renan\\codes\\Imagem com erro\\387.png', 'C:\\Users\\USER\\Documents\\Planilhas Renan\\codes\\Imagem com erro\\390.png', 'C:\\Users\\USER\\Documents\\Planilhas Renan\\codes\\Imagem com erro\\4062.png', 'C:\\Users\\USER\\Documents\\Planilhas Renan\\codes\\Imagem com erro\\425.png', 'C:\\Users\\USER\\Documents\\Planilhas Renan\\codes\\Imagem c ...
# Arquivos encontrados para a extensão *.gif: []
# Arquivos encontrados para a extensão *.bmp: []
# Arquivos encontrados para a extensão *.tiff: []
# (313 À 316).png
# 1028.png
# 10G.png
# 114.3.png
# 122.png
# 134.png
# 1427.png
# 1452.png
# 1722.png
# 173.png
# 2024.png
# 2069.png
# 2076.png
# 2182.png
# 2188.png
# 2194 COR 1,2,3.png
# 228.png
# 2407.png
# 29.1.png
# 2908.png
# 2913.png
# 3008.png
# 304.png
# 3057.png
# 3069.png
# 3071.png
# 3076.png
# 3078.1.png
# 3080.png
# 3082.png
# 3090.png
# 3112.png
# 3135.png
# 316.png
# 318.png
# 319.png
# 3228.png
# 3233.png
# 3259.png
# 3328.png
# 3341.png
# 3415.png
# 3687.png
# 37.png
# 387.png
# 390.png
# 4062.png
# 425.png
# 452 SANTA CLARA.png
# 482.png
# 4976.png
# 4978.png
# 522-C.png
# 5417.png
# 61.png
# 715.png
# 722.png
# 7301-026Z1.png
# 7301-411B3.png
# 7601-007Z.png
# 798.png
# 8020.png
# 890.png
# 9006-700G.png
# 9008-700L.png
# 942.png
# BASE MAX.png
# BATOM LIQ. ANDROMEDA.png
# BATOM LIQ. PEGASUS.png
# BF10013.png
# BF10046.png
# BF7533.png
# CA001.png
# CD-MH.png
# CGN010.png
# CS3634 COR 1_2.png
# ED003.png
# EP 15.png
# FDK BALA 05.png
# FDK BASE 20.png
# GEP-MV.png
# HB102257.png
# HB102265.png
# hb86508.png
# JS20002-B.png
# JSJ17008.png
# LIP BALM ML.png
# MF-6314.png
# MF0571.png
# MF7311.png
# MR005.png
# MR060.png
# PAPEL S_CAIXA 50.png
# PB1075.png
# PEDRA POMES 1082.png
# PH008.png
# PH0587.png
# PH0588.png
# PH0661.png
# PH0718.png
# PN-MV.png
# S 134.png
# SP243.png
# SP305 COR A.png
# ST 246.png
# W105.png
# W106.png
# W107.png
# W111.png
# W136.png
# W139.png
# W145.png
# W910.png

# %%
extensoes_imagem = ['*.jpg', '*.jpeg', '*.png', '*.gif', '*.bmp', '*.tiff']

# %%
arquivos_imagens = []

# %%
for extensao in extensoes_imagem:
    arquivos_imagens.extend(glob.glob(os.path.join(caminho_pasta, extensao)))


for arquivo in arquivos_imagens:
    print(os.path.basename(arquivo))
